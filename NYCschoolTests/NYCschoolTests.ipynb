# %% [markdown]
# ![New York City schoolbus](schoolbus.jpg)
#
# Photo by [Jannis Lucas](https://unsplash.com/@jannis_lucas) on [Unsplash](https://unsplash.com).
# <br>
#
# Every year, American high school students take SATs, which are standardized tests intended to measure literacy, numeracy, and writing skills. There are three sections - reading, math, and writing, each with a **maximum score of 800 points**. These tests are extremely important for students and colleges, as they play a pivotal role in the admissions process.
#
# Analyzing the performance of schools is important for a variety of stakeholders, including policy and education professionals, researchers, government, and even parents considering which school their children should attend.
#
# You have been provided with a dataset called `schools.csv`, which is previewed below.
#
# You have been tasked with answering three key questions about New York City (NYC) public school SAT performance.

# %%
# Re-run this cell 
import pandas as pd

# Read in the data
schools = pd.read_csv("schools.csv")
df = pd.read_csv("schools.csv")
# Preview the data
schools

# Start coding here...
# Add as many cells as you like...
# Out:
#                                            school_name  ... percent_tested
# 0    New Explorations into Science, Technology and ...  ...            NaN
# 1                                 Essex Street Academy  ...           78.9
# 2                         Lower Manhattan Arts Academy  ...           65.1
# 3      High School for Dual Language and Asian Studies  ...           95.9
# 4        Henry Street School for International Studies  ...           59.7
# ..                                                 ...  ...            ...
# 370  Queens High School for Information, Research, ...  ...           44.6
# 371  Rockaway Park High School for Environmental Su...  ...           38.5
# 372                   Channel View School for Research  ...           76.6
# 373                    Rockaway Collegiate High School  ...           46.5
# 374                                  Scholars' Academy  ...           99.2
#
# [375 rows x 7 columns]

# %%
schools.sort_values(by="average_math",ascending = False)
schools
# Out:
#                                            school_name  ... percent_tested
# 0    New Explorations into Science, Technology and ...  ...            NaN
# 1                                 Essex Street Academy  ...           78.9
# 2                         Lower Manhattan Arts Academy  ...           65.1
# 3      High School for Dual Language and Asian Studies  ...           95.9
# 4        Henry Street School for International Studies  ...           59.7
# ..                                                 ...  ...            ...
# 370  Queens High School for Information, Research, ...  ...           44.6
# 371  Rockaway Park High School for Environmental Su...  ...           38.5
# 372                   Channel View School for Research  ...           76.6
# 373                    Rockaway Collegiate High School  ...           46.5
# 374                                  Scholars' Academy  ...           99.2
#
# [375 rows x 7 columns]

# %%
schools["mathper"] = schools["average_math"] /800
schools["mathper"] = schools["mathper"].round(2)
schools.sort_values(by = "mathper",ascending = False)
# Out:
#                                            school_name  ... mathper
# 88                              Stuyvesant High School  ...    0.94
# 93                 Staten Island Technical High School  ...    0.89
# 170                       Bronx High School of Science  ...    0.89
# 365  Queens High School for the Sciences at York Co...  ...    0.88
# 333                        Townsend Harris High School  ...    0.85
# ..                                                 ...  ...     ...
# 337             Pan American International High School  ...    0.42
# 234  Dr. Susan S. McKinney Secondary School of the ...  ...    0.42
# 242  W. H. Maxwell Career and Technical Education H...  ...    0.41
# 247                          Multicultural High School  ...    0.40
# 182   Pan American International High School at Monroe  ...    0.40
#
# [375 rows x 8 columns]

# %%
best_math_schools = schools.loc[(schools["mathper"] > 0.79), ["average_math", "school_name"]]
best_math_schools = best_math_schools.sort_values(by ="average_math",ascending = False)
best_math_schools
# Out:
#      average_math                                        school_name
# 88            754                             Stuyvesant High School
# 170           714                       Bronx High School of Science
# 93            711                Staten Island Technical High School
# 365           701  Queens High School for the Sciences at York Co...
# 68            683  High School for Mathematics, Science, and Engi...
# 280           682                     Brooklyn Technical High School
# 333           680                        Townsend Harris High School
# 174           669  High School of American Studies at Lehman College
# 0             657  New Explorations into Science, Technology and ...
# 45            641                      Eleanor Roosevelt High School

# %%
# The "percent_tested" column likely represents the percentage of students who took the test.
# To understand it better, let's look at the distribution of values in the "percent_tested" column.

schools["percent_tested"].describe()
# Out:
# count    355.000000
# mean      64.976338
# std       18.747634
# min       18.500000
# 25%       50.950000
# 50%       64.800000
# 75%       79.600000
# max      100.000000
# Name: percent_tested, dtype: float64

# %%
# Add a new column "total_SAT" which is the sum of average_math, average_reading, and average_writing divided by 3
schools["total_SAT"] = (schools["average_math"] + schools["average_reading"] + schools["average_writing"]) 
schools["total_SAT"] = schools["total_SAT"].round(2)

# Add a new column "total_SAT_perc" which is the percentage of the total SAT score
schools["total_SAT_perc"] = (schools["total_SAT"] / 800).round(2)

# Display the updated DataFrame
schools.head()
# Out:
#                                          school_name  ... total_SAT_perc
# 0  New Explorations into Science, Technology and ...  ...           2.32
# 1                               Essex Street Academy  ...           1.49
# 2                       Lower Manhattan Arts Academy  ...           1.58
# 3    High School for Dual Language and Asian Studies  ...           1.91
# 4      Henry Street School for International Studies  ...           1.50
#
# [5 rows x 10 columns]

# %%
# Sort the DataFrame by "total_SAT" and "total_SAT_perc" in descending order
sorted_schools = schools.sort_values(by=["total_SAT", "total_SAT_perc"], ascending=False)

# Create a new DataFrame with only the "school_name", "total_SAT", and "total_SAT_perc" columns
sorted_schools_df = sorted_schools[["school_name", "total_SAT", "total_SAT_perc"]]

# Display the new DataFrame
sorted_schools_df
top_10_schools = sorted_schools_df.head(10)
top_10_schools = top_10_schools[["school_name","total_SAT"]]
top_10_schools
# Out:
#                                            school_name  total_SAT
# 88                              Stuyvesant High School       2144
# 93                 Staten Island Technical High School       2041
# 170                       Bronx High School of Science       2041
# 174  High School of American Studies at Lehman College       2013
# 333                        Townsend Harris High School       1981
# 365  Queens High School for the Sciences at York Co...       1947
# 5                       Bard High School Early College       1914
# 280                     Brooklyn Technical High School       1896
# 45                       Eleanor Roosevelt High School       1889
# 68   High School for Mathematics, Science, and Engi...       1889

# %%
schools["stdtotal"] = schools["total_SAT"].std().round(2)
schools
# Out:
#                                            school_name  ... stdtotal
# 0    New Explorations into Science, Technology and ...  ...   194.91
# 1                                 Essex Street Academy  ...   194.91
# 2                         Lower Manhattan Arts Academy  ...   194.91
# 3      High School for Dual Language and Asian Studies  ...   194.91
# 4        Henry Street School for International Studies  ...   194.91
# ..                                                 ...  ...      ...
# 370  Queens High School for Information, Research, ...  ...   194.91
# 371  Rockaway Park High School for Environmental Su...  ...   194.91
# 372                   Channel View School for Research  ...   194.91
# 373                    Rockaway Collegiate High School  ...   194.91
# 374                                  Scholars' Academy  ...   194.91
#
# [375 rows x 11 columns]

# %%
#schools = schools.drop(columnss ="average_SAT")
schools= schools.drop(columns ="stdtotal")
schools
# Out:
#                                            school_name  ... total_SAT_perc
# 0    New Explorations into Science, Technology and ...  ...           2.32
# 1                                 Essex Street Academy  ...           1.49
# 2                         Lower Manhattan Arts Academy  ...           1.58
# 3      High School for Dual Language and Asian Studies  ...           1.91
# 4        Henry Street School for International Studies  ...           1.50
# ..                                                 ...  ...            ...
# 370  Queens High School for Information, Research, ...  ...           1.36
# 371  Rockaway Park High School for Environmental Su...  ...           1.39
# 372                   Channel View School for Research  ...           1.60
# 373                    Rockaway Collegiate High School  ...           1.51
# 374                                  Scholars' Academy  ...           2.14
#
# [375 rows x 10 columns]

# %%
schools["stdttotal"] = schools[["average_math" , "average_reading", "average_writing"]].std(axis = 1).round(2)
schools
# Out:
#                                            school_name  ... stdttotal
# 0    New Explorations into Science, Technology and ...  ...     32.33
# 1                                 Essex Street Academy  ...     12.22
# 2                         Lower Manhattan Arts Academy  ...      6.81
# 3      High School for Dual Language and Asian Studies  ...     89.63
# 4        Henry Street School for International Studies  ...     15.72
# ..                                                 ...  ...       ...
# 370  Queens High School for Information, Research, ...  ...     10.00
# 371  Rockaway Park High School for Environmental Su...  ...     12.66
# 372                   Channel View School for Research  ...      3.51
# 373                    Rockaway Collegiate High School  ...      3.06
# 374                                  Scholars' Academy  ...     14.42
#
# [375 rows x 11 columns]

# %%
schools["average_SAT"]  = schools["total_SAT"].mean().round(2)
schools
# Out:
#                                            school_name  ... average_SAT
# 0    New Explorations into Science, Technology and ...  ...     1275.91
# 1                                 Essex Street Academy  ...     1275.91
# 2                         Lower Manhattan Arts Academy  ...     1275.91
# 3      High School for Dual Language and Asian Studies  ...     1275.91
# 4        Henry Street School for International Studies  ...     1275.91
# ..                                                 ...  ...         ...
# 370  Queens High School for Information, Research, ...  ...     1275.91
# 371  Rockaway Park High School for Environmental Su...  ...     1275.91
# 372                   Channel View School for Research  ...     1275.91
# 373                    Rockaway Collegiate High School  ...     1275.91
# 374                                  Scholars' Academy  ...     1275.91
#
# [375 rows x 12 columns]

# %%
boroughs = schools.groupby("borough")["total_SAT"].agg(["count","mean","std"]).round(2)

# %%
largest_std_dev = boroughs[boroughs["std"] == boroughs["std"].max()]
largest_std_dev = largest_std_dev.rename(columns= {"count":"num_schools" , "mean":"average_SAT","std":"std_SAT"})
largest_std_dev
# Out:
#            num_schools  average_SAT  std_SAT
# borough
# Manhattan           89      1340.13   230.29
